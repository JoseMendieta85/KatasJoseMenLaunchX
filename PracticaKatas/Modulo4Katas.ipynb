# %%
#Ejercicio 1: Transformar cadenas
#En este ejercicio, usarás métodos de cadena para modificar el texto con hechos sobre la Luna 
# y luego extraerás información para crear un breve resumen.

print ('**EJERCICIO 1**')
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. 
There are several interesting facts about the Moon and how it affects life here on Earth. 
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not 
significant enough to cause immediate effects on Earth. The highest daylight temperature 
of the Moon is 127 C."""

#Primero, divide el texto en cada oración para trabajar con su contenido:
text0 = text.lower()
text1 = text0.split('.')
print ('>TEXTO DIVIDIDO Y FORMATO MINUSCULAS')
print(text1)


#Define algunas palabras clave para búsqueda que te ayudarán a determinar 
#si una oración contiene un hecho.
#Define las palabras pista: average, temperature y distance suenan bien
claves = ["average", "temperature", "distance"]

#Crea un bucle para imprimir solo datos sobre la Luna que estén relacionados con 
# las palabras clave definidas anteriormente
print ('\n>RESUMEN CON PALABRAS CLAVE')
for i in text1:
    for j in claves:
        if j in i:
            print(i)

#Finalmente, actualiza el bucle(ciclo) para cambiar C a Celsius:
print ('\n>REEMPLAZAR C CON CELSIUS')
for i in text1:
    for j in claves:
        if j in i:
            print(i.replace(' c', ' Celsius'))
# Out:
# **EJERCICIO 1**
# >TEXTO DIVIDIDO Y FORMATO MINUSCULAS
# ['interesting facts about the moon', " the moon is earth's only satellite", ' \nthere are several interesting facts about the moon and how it affects life here on earth', ' \non average, the moon moves 4cm away from the earth every year', ' this yearly drift is not \nsignificant enough to cause immediate effects on earth', ' the highest daylight temperature \nof the moon is 127 c', '']
#
# >RESUMEN CON PALABRAS CLAVE
#
# on average, the moon moves 4cm away from the earth every year
#  the highest daylight temperature
# of the moon is 127 c
#
# >REEMPLAZAR C CON CELSIUS
#
# on average, the moon moves 4cm away from the earth every year
#  the highest daylight temperature
# of the moon is 127 Celsius

# %%
print ("*EJERCICIO 2**")

#Ejercicio 2: Formateando Cadenas
#En este ejercicio, se utilizan variables que contienen datos clave sobre la gravedad en 
#varias lunas y luego se utilizan para dar formato e imprimir la información.
# El formato tiene que acomodar información sobre otras lunas, por lo que debe ser genérico.
# En lugar de reemplazar las variables en una cadena larga como parte de un párrafo, 
# utiliza la información para presentarla en un formato tabular. El resultado debería verse así:

#Gravity Facts about Ganymede
#-------------------------------------------------------------------------------
#Planet Name: Mars
#Gravity on Ganymede: 1.4300000000000002 m/s2

# Datos con los que vas a trabajar
name = 'Moon'
gravity = 0.00162 # in kms
planet = 'Earth'


#Primero, crea un título para el texto. 
#Debido a que este texto trata sobre la gravedad en la Tierra y la Luna, 
#úsalo para crear un título significativo. Utiliza las variables en lugar de escribir.
# Creamos el título
#title = "Gravity Facts about " + name
title2 = f'Gravity Facts about {name}'

#Ahora crea una plantilla de cadena multilínea para contener el resto de la información. 
#En lugar de usar kilómetros, debes convertir la distancia a metros multiplicando por 1,000.
# Creamos la plantilla
#linea = "\n--------------------------------------------------------------------------------"
#datos = "\nPlanet Name " + planet + "\nGravedad en " + name +" " + str(gravity * 1000) + " m/s2"
datos2 = f"""{'-'*80} 
Planet Name: {planet} 
Gravedad en {name}: {gravity * 1000} m/s2
"""

#Finalmente, usa ambas variables para unir el título y los hechos. 
#Unión de ambas cadenas
#union = title + linea + datos
union2 = f"""{title2.title()} 
{datos2}"""
print(union2)


#Ahora usa información de una luna diferente para ver si la plantilla todavía funciona.
name = 'Ganímedes'
gravity  = 0.00143
planet = 'Marte '
print(union2)

#La salida no muestra información sobre Marte. Todavía muestra información sobre la Luna. 
#Esto sucede porque las cadenas f están ansiosas en su evaluación, por lo que las variables 
#una vez asignadas no se pueden reasignar. Para evitar este problema, vuelva a hacer la 
#plantilla para utilizar .format():
# Nueva plantilla
new_template = """
Datos de Gravedad sobre: {name}
-------------------------------------------------------------------------------
Nombre del planeta: {planet}
Gravedad en {name}: {gravity} m/s2
"""
print(new_template.format(name=name, planet=planet, gravity=gravity))

#Debido a que .format() no permite expresiones, la gravedad en Ganímedes es incorrecta. 
#Asegúrese de que la operación se realiza fuera de la plantilla de formato e imprima de nuevo 
#para ver el resultado de trabajo.
#Pista: print(nueva_plantilla.format(variables))
print(new_template.format(name=name, planet=planet, gravity=gravity*1000))
# Out:
# *EJERCICIO 2**
# Gravity Facts About Moon
# --------------------------------------------------------------------------------
# Planet Name: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2
#
# Gravity Facts About Moon
# --------------------------------------------------------------------------------
# Planet Name: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2
#
#
# Datos de Gravedad sobre: Ganímedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 0.00143 m/s2
#
#
# Datos de Gravedad sobre: Ganímedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s2
